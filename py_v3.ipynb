# %% [markdown]
# <a href="https://colab.research.google.com/github/munakata255/Python_study/blob/main/py_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#11/2

# %%
print(8)
a=8
print(f"{a}")
print("8")
# Out:
# 8
# 8
# 8

# %%
print(8,"\n\n")
print("13")
# Out:
# 8
#
#
# 13

# %%
print(f"{10}")
# Out:
# 10

# %%
#f文字の使い方
print(f"固定文字")            # 普通の文字列
print(f"{3*5}")               # 式の結果を出力
print(f"{'abc'.upper()}")     # 関数の結果を出力

# %%
print(f"{7:05}")
# Out:
# 00007

# %%
print("{:05}".format(7))
# Out:
# 00007

# %%
print("|{:*^7}|".format(7))
# Out:
# |***7***|

# %%
print("|{:*>7}|".format(7))
# Out:
# |******7|

# %%
print("A", end="")
print("B")
# Out:
# AB

# %%
S = "Hello"
N=len(S)
print(N)
# Out:
# 5

# %%
S=input()
print(f"+{S}+")
print("++")

# %%
# coding: utf-8
# 自分の得意な言語で
# Let's チャレンジ！！
# tt=[[],[]]
N,H,W = map(int,input().split())
sy,sx = map(int,input().split())
s=input()
for _ in range(H):
  c.append=[list(map(int,input().split()))]
for i in range(len(s)):
    if "F"==s[i]:
        sy-=1
    if "B"==s[i]:
        sy+=1
    if "L"==s[i]:
         sx-=1
    if "R"==s[i]:
         sx+=1
    print(c[sy-1][sx-1])

# %%
# coding: utf-8
# 自分の得意な言語で
# Let's チャレンジ！！
# tt=[[],[]]
N,H,W = map(int,input().split())
sy,sx = map(int,input().split())
s=input()
c=[list(map(int,input().split())) for _ in range(H)]
for i in range(len(s)):
    if "F"==s[i]:
        sy-=1
    if "B"==s[i]:
        sy+=1
    if "L"==s[i]:
         sx-=1
    if "R"==s[i]:
         sx+=1
    print(c[sy-1][sx-1])
